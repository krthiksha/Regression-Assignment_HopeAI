# %% [markdown]
# # Random Forest Regressor Algorithm -  insurance_charge_prediction
# ## MODEL CREATION PHASE

# %% [markdown]
# ## read the dataset

# %%
import pandas as pd 
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## convert categorical data into numerical data

# %%
dataset = pd.get_dummies(dataset,drop_first=True,dtype=int)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## split Input and Output

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes' ]]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %% [markdown]
# ## split train and test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.20, random_state=0)

# %%
x_test
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 578    52  30.200         1         1           0
# 610    47  29.370         1         0           0
# 569    48  40.565         2         1           1
# 1034   61  38.380         0         1           0
# 198    51  18.050         0         0           0
# ...   ...     ...       ...       ...         ...
# 1084   62  30.495         2         0           0
# 726    41  28.405         1         1           0
# 1132   57  40.280         0         1           0
# 725    30  39.050         3         0           1
# 963    46  24.795         3         1           0
#
# [268 rows x 5 columns]

# %%
y_test
# Out:
#           charges
# 578    9724.53000
# 610    8547.69130
# 569   45702.02235
# 1034  12950.07120
# 198    9644.25250
# ...           ...
# 1084  15019.76005
# 726    6664.68595
# 1132  20709.02034
# 725   40932.42950
# 963    9500.57305
#
# [268 rows x 1 columns]

# %% [markdown]
# ## model creation

# %%
from sklearn.ensemble import RandomForestRegressor
# criterion   {“squared_error”, “friedman_mse”, “absolute_error”, “poisson”}, default=”mse"
regressor = RandomForestRegressor(n_estimators=100,random_state=0, criterion="poisson")
regressor.fit(x_train, y_train)
# Out:
# E:\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(criterion='poisson', random_state=0)

# %% [markdown]
# ## test the model

# %%
y_predict = regressor.predict(x_test)
y_predict
# Out:
# array([10993.2335024 ,  9748.5788321 , 44878.8309195 , 13152.3050665 ,
#         9282.2442225 , 13491.9698838 ,  1905.59865967, 11288.5741486 ,
#         7543.7893805 ,  5153.8555865 ,  7708.1822478 , 15992.1603201 ,
#        11154.4961825 ,  6207.0246374 , 25387.7669653 , 12492.3347428 ,
#        12940.6454799 ,  6678.0149509 ,  6371.404419  , 33900.576886  ,
#        23970.2493305 , 12975.5881142 , 11003.9196862 , 28052.9433683 ,
#         2178.6481467 ,  4833.5402853 ,  5470.9374051 ,  7887.191776  ,
#         3723.620363  ,  9238.175171  ,  7718.6208295 , 48373.673503  ,
#        14415.013667  , 11088.585861  , 15812.3124747 ,  3732.487848  ,
#         8992.5408872 , 37630.1287039 , 39602.433135  ,  2499.3430638 ,
#        11696.8944043 ,  3736.1282499 , 20453.4472485 , 47234.2193055 ,
#        36640.2103251 ,  4563.0624443 , 12688.3496138 ,  6660.23329   ,
#         4962.1132945 , 12479.8904726 ,  3329.5294683 , 12281.6745957 ,
#        26454.8290769 , 47393.289457  , 11953.9578785 ,  7321.5867522 ,
#         3751.4442851 , 10007.3002518 ,  9540.9274589 , 18022.4897607 ,
#         1649.0469355 , 47677.1633762 , 16167.8665794 , 15914.1957448 ,
#        13503.4982851 ,  9808.027162  , 33801.189034  , 40454.139491  ,
#         4343.3984804 , 10920.5110066 , 19205.7627774 , 13230.9116639 ,
#        18419.1503665 , 14171.0170466 , 13232.4458009 , 14767.7734018 ,
#         8367.0308778 , 14806.3571558 , 19723.057669  , 47398.395872  ,
#        11518.4169965 , 49134.6303732 ,  3191.3487648 , 10771.5471051 ,
#        40635.8179595 , 19272.277483  ,  4766.4126006 ,  3549.3326779 ,
#        15121.5387671 , 38958.3925839 ,  5529.0337477 , 13765.1225274 ,
#         2857.8954015 , 10521.0655786 ,  5696.8985153 ,  4388.1629705 ,
#        43283.4439673 , 52263.8992353 ,  5311.8649128 , 10845.3399815 ,
#         3444.1340555 ,  6397.0820648 ,  9352.976649  , 39119.9034257 ,
#        27836.2385301 ,  3360.7971495 , 11360.7120675 ,  6642.5482724 ,
#        11617.8261665 , 45510.933855  , 12348.2802752 ,  6918.465749  ,
#        10170.2471232 , 34264.3378933 , 47725.696762  ,  7159.7559858 ,
#         2357.6471104 , 11922.3503597 , 23243.1797063 ,  9578.9441131 ,
#        41818.1090919 , 12274.1410969 , 14613.493975  ,  7219.1638422 ,
#        11135.3417166 ,  5237.2766351 , 26619.6125838 , 26139.6738097 ,
#        48283.304381  ,  1989.7627046 , 16809.2792954 ,  3935.3879967 ,
#         6079.5716413 ,  9216.3927204 , 41390.0291807 , 38450.4013462 ,
#        24008.9083656 , 13999.0757303 , 24071.6984949 ,  7087.8201791 ,
#         1985.810813  , 11962.7008019 , 10607.2015103 , 11029.917895  ,
#         6932.2316021 , 14211.306712  , 24165.1454283 , 11660.0610294 ,
#         1596.9325155 , 12481.3911861 ,  6017.041364  , 39323.651576  ,
#         9554.4391304 ,  7605.79822786,  4873.24893263,  9050.5279875 ,
#         3514.2909314 ,  6206.64732455, 12492.3347428 , 11689.8928682 ,
#         8700.1062788 , 13265.5760375 , 13543.2980012 ,  9229.182455  ,
#         4348.8732213 ,  8991.7023903 , 15189.0420602 ,  6710.4237422 ,
#         4605.9446517 ,  2078.75122983,  9327.9380581 ,  6826.2693908 ,
#        12624.2106909 ,  2255.0295733 , 10852.3939065 ,  9090.3613894 ,
#         4348.8277413 ,  7171.4498151 , 27570.084973  ,  1714.1426685 ,
#        17137.0376009 ,  6455.9682685 , 11479.9664185 ,  8953.1438106 ,
#         8796.929244  , 27987.3340385 ,  2909.1412823 ,  2882.2138288 ,
#        14164.0797305 , 11360.5422306 , 41406.436823  ,  5341.4255498 ,
#         5393.4206675 , 24275.8105172 ,  3380.4589821 ,  2457.8495645 ,
#         9852.689272  ,  6020.3401216 ,  8651.029131  ,  4241.302316  ,
#        11730.097893  , 47171.5238932 , 15194.7585922 , 18839.9377585 ,
#         6403.8709551 , 43460.7810992 ,  4182.3865953 ,  9919.3312804 ,
#         6370.5916654 ,  1304.7061245 ,  9761.6772515 , 13620.9015195 ,
#         6386.3325163 ,  3621.268905  ,  6511.2279645 ,  9868.4248317 ,
#         7215.9941093 ,  6389.1869362 , 14148.0687921 ,  6734.1181639 ,
#        12188.2822588 ,  8036.3043354 , 12697.4833401 ,  7570.4386354 ,
#        14690.1548321 , 14413.25868   , 20882.5051199 , 12078.2342528 ,
#         7136.8516747 ,  2752.03787   ,  7496.40558695,  8282.048622  ,
#        14735.215232  ,  5955.8574472 ,  5147.699713  ,  7185.9255335 ,
#        13741.3601246 , 34297.317474  ,  5668.826371  , 12513.0390272 ,
#         5805.5131024 , 37375.431941  ,  8483.5638217 ,  7195.9599172 ,
#        13220.2503015 , 14403.3959918 ,  5008.8833415 ,  8169.2117598 ,
#         2245.7849485 ,  6439.1955725 , 19148.9316025 , 46633.0919235 ,
#         4887.9046808 ,  5154.6588464 ,  5036.94591832,  1628.918212  ,
#         8222.8252895 ,  2764.31497225,  7133.4682502 , 10881.2790177 ,
#         8750.551759  , 25262.9393575 , 46180.745469  , 16285.1463222 ,
#         6511.4743855 , 11188.9820405 , 43037.8257602 ,  9723.6639664 ])

# %% [markdown]
# ## Evaluation metrics

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test, y_predict)
print(f" THE ACCURACY OF THE MODEL : {r_score}")
# Out:
#  THE ACCURACY OF THE MODEL : 0.875772611487943

# %% [markdown]
# ## save the model

# %%
import pickle 
pickle.dump(regressor, open("insurance_charge_finalModel_RF_regressor.sav","wb"))

# %% [markdown]
# ## load and predict the model

# %%
insurance_charge_predict = pickle.load(open("insurance_charge_finalModel_RF_regressor.sav","rb"))
insurance_charge_predict.predict([[ 52, 30.200, 1, 1, 0 ]])
# Out:
# E:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([10993.2335024])
