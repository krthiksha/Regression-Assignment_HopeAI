# %% [markdown]
# # Decision Tree Algorithm - insurance_charge_prediction
# ## MODEL CREATION PHASE

# %% [markdown]
# ## read the dataset

# %%
import pandas as pd 
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## convert categorical data into numerical data

# %%
dataset = pd.get_dummies(dataset,drop_first=True,dtype=int)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %% [markdown]
# ## split Input and Output

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes' ]]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %% [markdown]
# ## split train and test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.20, random_state=0)

# %%
x_test
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 578    52  30.200         1         1           0
# 610    47  29.370         1         0           0
# 569    48  40.565         2         1           1
# 1034   61  38.380         0         1           0
# 198    51  18.050         0         0           0
# ...   ...     ...       ...       ...         ...
# 1084   62  30.495         2         0           0
# 726    41  28.405         1         1           0
# 1132   57  40.280         0         1           0
# 725    30  39.050         3         0           1
# 963    46  24.795         3         1           0
#
# [268 rows x 5 columns]

# %%
y_test
# Out:
#           charges
# 578    9724.53000
# 610    8547.69130
# 569   45702.02235
# 1034  12950.07120
# 198    9644.25250
# ...           ...
# 1084  15019.76005
# 726    6664.68595
# 1132  20709.02034
# 725   40932.42950
# 963    9500.57305
#
# [268 rows x 1 columns]

# %% [markdown]
# ## model creation

# %%
import matplotlib.pyplot as plt 
from sklearn import tree 
tree.plot_tree(regressor)
plt.show()

# %%
"""
criterion   {“squared_error”, “friedman_mse”, “absolute_error”, “poisson”}, default=”squared_error”
splitter   {“best”, “random”}, default=”best”
max_features  int, float or {“sqrt”, “log2”}, default=None
"""
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(criterion="absolute_error",splitter="best",random_state=0, max_features="sqrt")
regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='absolute_error', max_features='sqrt',
#                       random_state=0)

# %% [markdown]
# ### Tree visualization

# %% [markdown]
# ## test the model

# %%
y_predict = regressor.predict(x_test)
y_predict
# Out:
# array([ 9377.9047  ,  7050.642   , 44202.6536  , 12574.049   ,
#         9264.797   , 21984.47061 ,  1615.7667  , 11411.685   ,
#         7151.092   ,  5325.651   ,  4827.90495 , 11150.78    ,
#        11881.358   ,  4992.3764  , 18246.4955  , 10381.4787  ,
#        12142.5786  ,  3292.52985 ,  6455.86265 , 33750.2918  ,
#        24869.8368  , 12269.68865 ,  9625.92    , 21774.32215 ,
#         1682.597   ,  3875.7341  ,  2527.81865 ,  7418.522   ,
#         5227.98875 ,  8027.968   ,  7151.092   , 48673.5588  ,
#        12981.3457  , 10226.2842  , 16420.49455 ,  3554.203   ,
#         8733.22925 , 36950.2567  , 40941.2854  ,  1880.07    ,
#         2527.81865 ,  2866.091   , 19350.3689  , 49577.6624  ,
#        36307.7983  ,  2801.2588  , 10381.4787  ,  6272.4772  ,
#         4719.52405 , 26236.57997 ,  2473.3341  ,  4466.6214  ,
#        27218.43725 , 44400.4064  , 11093.6229  , 19673.33573 ,
#         2897.3235  ,  8782.469   ,  8965.79575 ,  8604.48365 ,
#         1635.73365 , 41999.52    , 27941.28758 , 25333.33284 ,
#        10407.08585 ,  9877.6077  , 33750.2918  , 44585.45587 ,
#         2913.569   , 15828.82173 , 13429.0354  , 12925.886   ,
#        17085.2676  , 13887.204   , 12629.8967  , 12638.195   ,
#         6250.435   ,  8027.968   , 21771.3423  , 48517.56315 ,
#        11658.11505 , 43896.3763  ,  1682.597   ,  7147.4728  ,
#        40273.6455  , 19040.876   ,  3766.8838  ,  2897.3235  ,
#        12913.9924  , 36950.2567  ,  6128.79745 , 24476.47851 ,
#         3021.80915 ,  8232.6388  ,  3935.1799  ,  4738.2682  ,
#        39727.614   , 43943.8761  ,  5375.038   , 10601.412   ,
#         1815.8759  ,  6600.20595 ,  4753.6368  , 55135.40209 ,
#        24915.22085 ,  3176.2877  , 11165.41765 ,  3172.018   ,
#        11743.9341  , 39125.33225 , 12094.478   ,  4463.2051  ,
#         7050.642   , 34617.84065 , 48673.5588  ,  7256.7231  ,
#         2362.22905 ,  8782.469   , 11945.1327  ,  8615.3     ,
#        40103.89    ,  9264.797   , 13063.883   ,  4449.462   ,
#        28340.18885 ,  2913.569   , 21771.3423  , 35069.37452 ,
#        48673.5588  ,  1534.3045  , 11881.358   ,  1727.54    ,
#         6238.298   ,  8688.85885 , 37829.7242  , 39727.614   ,
#        17904.52705 , 10156.7832  , 21677.28345 ,  2416.955   ,
#         1877.9294  , 10796.35025 ,  8978.1851  , 10601.63225 ,
#        21984.47061 , 13887.204   , 31620.00106 ,  2913.569   ,
#         1832.094   , 10436.096   ,  6496.886   , 38126.2465  ,
#         8964.06055 , 11272.33139 ,  2219.4451  ,  5974.3847  ,
#         2639.0429  , 11272.33139 , 10381.4787  ,  9414.92    ,
#         4449.462   , 12981.3457  , 12629.8967  ,  9048.0273  ,
#         2527.81865 ,  4915.05985 , 20167.33603 , 18804.7524  ,
#         4239.89265 ,  2217.46915 ,  3877.30425 ,  4438.2634  ,
#        19144.57652 ,  1826.843   , 18804.7524  ,  4915.05985 ,
#         3847.674   ,  6123.5688  , 23807.2406  ,  1708.0014  ,
#        29186.48236 ,  5253.524   , 11353.2276  ,  2497.0383  ,
#        11737.84884 , 26109.32905 ,  1682.597   ,  2710.82855 ,
#        13880.949   , 10043.249   , 41919.097   ,  4564.19145 ,
#         6496.886   , 24869.8368  ,  2727.3951  ,  1977.815   ,
#         6203.90175 ,  5972.378   ,  4463.2051  ,  4040.55825 ,
#        11879.10405 , 47055.5321  , 29186.48236 , 19040.876   ,
#         4433.9159  , 38511.6283  ,  3484.331   ,  9722.7695  ,
#         5989.52365 ,  1146.7966  ,  8964.06055 , 13844.7972  ,
#         4391.652   ,  2855.43755 ,  5484.4673  ,  2352.96845 ,
#         6548.19505 ,  4719.52405 , 14001.1338  ,  6686.4313  ,
#         6184.2994  ,  7985.815   ,  8280.6227  , 25081.76784 ,
#        12430.95335 , 14410.9321  , 12269.68865 , 12222.8983  ,
#         3861.20965 ,  3309.7926  ,  1712.227   ,  8334.5896  ,
#        12644.589   , 24671.66334 , 23288.9284  ,  7256.7231  ,
#         9447.25035 , 39727.614   ,  4454.40265 , 10156.7832  ,
#         5469.0066  , 38344.566   ,  7749.1564  ,  5266.3656  ,
#         8606.2174  , 10436.096   ,  3077.0955  ,  8823.98575 ,
#         2150.469   ,  6272.4772  , 18328.2381  , 43813.8661  ,
#         3925.7582  ,  3766.8838  , 11774.159275,  1704.70015 ,
#         7147.4728  ,  2211.13075 ,  5080.096   ,  3378.91    ,
#         8615.3     , 23887.6627  , 43813.8661  , 15230.32405 ,
#         5484.4673  , 10982.5013  , 40904.1995  ,  8615.3     ])

# %% [markdown]
# ## Evaluation metrics

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test, y_predict)
print(f" THE ACCURACY OF THE MODEL : {r_score}")    # THE ACCURACY OF THE MODEL : 0.7538062098354589   --- using criterion="absolute_error",splitter="random"
# Out:
#  THE ACCURACY OF THE MODEL : 0.7885524275111394

# %% [markdown]
# ## save the model

# %%
# import pickle 
# pickle.dump(regressor, open(" ","wb"))

# %%
regressor.predict([[ 52, 30.200, 1, 1, 0 ]])
# Out:
# E:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([9377.9047])
